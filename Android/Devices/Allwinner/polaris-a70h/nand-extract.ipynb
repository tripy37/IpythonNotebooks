# %% [markdown]
# We can connect to our device using the android tool adb
#
# You should have an adb server deamon running already with root

# %%
# !tools/adb shell "cat /proc/partitions"
# Out:
# major minor  #blocks  name
#
#   93        0      32768 nanda
#   93        8      16384 nandb
#   93       16      16384 nandc
#   93       24     786432 nandd
#   93       32    1048576 nande
#   93       40      16384 nandf
#   93       48      32768 nandg
#   93       56     131072 nandh
#   93       64     131072 nandi
#   93       72    4675584 nandj

# %%
ls -l tablet/
# Out:
# total 2211860
# drwxr-xr-x  3 kevin kevin       4096 Mar  7 17:17 boot/
# -rw-r--r--  1 kevin kevin   33554432 Mar  7 14:12 nanda.bootloader.img
# -rw-r--r--  1 kevin kevin   16777216 Mar  2 16:44 nandb.env.img
# -rw-r--r--  1 kevin kevin   16777216 Feb 28 16:44 nandc.boot.img
# -rw-r--r--  1 kevin kevin  805306368 Mar 13 23:49 nandd.system.img
# -rw-r--r--  1 kevin kevin 1073741824 Mar  2 22:12 nande.data.img
# -rw-r--r--  1 kevin kevin   16777216 Mar  2 22:39 nandf.misc.img
# -rw-r--r--  1 kevin kevin   33554432 Feb 28 19:40 nandg.recovery.img
# -rw-r--r--  1 kevin kevin  134217728 Mar  2 22:40 nandh.cache.img
# -rw-r--r--  1 kevin kevin  134217728 Mar  2 22:41 nandi.databk.img
# drwxr-xr-x  3 kevin kevin       4096 Mar  9 23:37 recovery/
# drwxr-xr-x 16 root  root        4096 Jan  1  1970 system/

# %%
# !tools/adb shell "cat system/build.prop"
# Out:
# # begin build properties
# # autogenerated by buildinfo.sh
# ro.build.id=JDQ39
# ro.build.display.id=polaris_eng 4.2.2 JDQ39 20140326 test-keys
# ro.build.version.incremental=20140326
# ro.build.version.sdk=17
# ro.build.version.codename=REL
# ro.build.version.release=4.2.2
# ro.build.date=Wed Mar 26 17:50:56 CST 2014
# ro.build.date.utc=1395827456
# ro.build.type=eng
# ro.build.user=android10
# ro.build.host=Linux2
# ro.build.tags=test-keys
# ro.product.model=GA10H
# ro.flash.condition=4294967296
# ro.flash.size=3543348019
# ro.product.brand=Allwinner-Tablet
# ro.product.name=polaris_a70H
# ro.product.device=polaris-a70H
# ro.product.board=exdroid
# ro.product.cpu.abi=armeabi-v7a
# ro.product.cpu.abi2=armeabi
# ro.product.manufacturer=unknown
# ro.product.locale.language=en
# ro.product.locale.region=US
# ro.wifi.channels=
# ro.board.platform=polaris
# # ro.build.product is obsolete; use ro.product.device
# ro.build.product=polaris-a70H
# ...

# %%
# !tools/adb shell "ls -al /dev/block/by-name"
# Out:
# lrwxrwxrwx root     root              2015-03-10 22:11 UDISK -> /dev/block/nandj
# lrwxrwxrwx root     root              2015-03-10 22:11 boot -> /dev/block/nandc
# lrwxrwxrwx root     root              2015-03-10 22:11 boot-resource -> /dev/block/nanda
# lrwxrwxrwx root     root              2015-03-10 22:11 cache -> /dev/block/nandh
# lrwxrwxrwx root     root              2015-03-10 22:11 data -> /dev/block/nande
# lrwxrwxrwx root     root              2015-03-10 22:11 databk -> /dev/block/nandi
# lrwxrwxrwx root     root              2015-03-10 22:11 env -> /dev/block/nandb
# lrwxrwxrwx root     root              2015-03-10 22:11 misc -> /dev/block/nandf
# lrwxrwxrwx root     root              2015-03-10 22:11 recovery -> /dev/block/nandg
# lrwxrwxrwx root     root              2015-03-10 22:11 system -> /dev/block/nandd

# %% [markdown]
# Lets create a backup or our tablet by extracting all the partitions.

# %%
# !tools/adb shell "dd if=/dev/block/nanda 2>/dev/null" | dd of=org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nanda.boot-resource.img
# Out:
# 65367+500 records in
# 65552+1 records out
# 33562881 bytes (34 MB) copied, 8.4137 s, 4.0 MB/s

# %%
# !tools/adb shell "dd if=/dev/block/nandb 2>/dev/null" | dd of=org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandb.env.img
# Out:
# 32768+0 records in
# 32768+0 records out
# 16777216 bytes (17 MB) copied, 4.04672 s, 4.1 MB/s

# %%
# !tools/adb shell "dd if=/dev/block/nandc 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandc.boot.img.gz

# %%
# !tools/adb shell "dd if=/dev/block/nandd 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandd.system.img.gz

# %%
# !tools/adb shell "dd if=/dev/block/nande 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nande.data.img.gz

# %%
# !tools/adb shell "dd if=/dev/block/nandf 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandf.misc.img.gz

# %%
# !tools/adb shell "dd if=/dev/block/nandg 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandg.recovery.img.gz

# %%
# !tools/adb shell "dd if=/dev/block/nandh 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandh.cache.img.gz

# %%
# !tools/adb shell "dd if=/dev/block/nandi 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandi.databk.img.gz

# %%
# !tools/adb shell "dd if=/dev/block/nandj 2>/dev/null" | gzip -c > org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandj.UDISK.img.gz

# %%
# !gunzip -c org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/nandc.boot.img.gz > tablet/nanda.boot-resource.img

# %%
ls -l tablet/
# Out:
# total 2228332
# drwxr-xr-x  3 kevin kevin       4096 Mar  7 17:17 boot/
# -rw-r--r--  1 kevin kevin   33554432 Mar  7 14:12 nanda.bootloader.img
# -rw-rw-r--  1 kevin kevin   16866141 Mar 14 00:46 nanda.boot-resource.img
# -rw-r--r--  1 kevin kevin   16777216 Mar  2 16:44 nandb.env.img
# -rw-r--r--  1 kevin kevin   16777216 Feb 28 16:44 nandc.boot.img
# -rw-r--r--  1 kevin kevin  805306368 Mar 13 23:49 nandd.system.img
# -rw-r--r--  1 kevin kevin 1073741824 Mar  2 22:12 nande.data.img
# -rw-r--r--  1 kevin kevin   16777216 Mar  2 22:39 nandf.misc.img
# -rw-r--r--  1 kevin kevin   33554432 Feb 28 19:40 nandg.recovery.img
# -rw-r--r--  1 kevin kevin  134217728 Mar  2 22:40 nandh.cache.img
# -rw-r--r--  1 kevin kevin  134217728 Mar  2 22:41 nandi.databk.img
# drwxr-xr-x  3 kevin kevin       4096 Mar  9 23:37 recovery/
# drwxr-xr-x 16 root  root        4096 Jan  1  1970 system/

# %%
ls -l org/Allwinner-Tablet/polaris_a70H/4.2.2/JDQ39/
# Out:
# total 873944
# -rw-r--r-- 1 kevin kevin    494493 Mar 11 01:33 nanda.boot-resource.img.gz
# -rw-r--r-- 1 kevin kevin     16599 Mar 11 08:36 nandb.env.img.gz
# -rw-r--r-- 1 kevin kevin   5610596 Mar 11 08:35 nandc.boot.img.gz
# -rw-r--r-- 1 kevin kevin 312248037 Mar 11 08:42 nandd.system.img.gz
# -rw-rw-r-- 1 kevin kevin 576536228 Mar 14 00:02 nande.data.img.gz
